# %% [markdown]
# # Customer Churn Analysis: Segmentation and Cohort Insights for Retention Strategy

# %% [markdown]
# ## Project Overview

# %% [markdown]
# Proyek ini bertujuan untuk menganalisis perilaku churn pelanggan pada perusahaan layanan telekomunikasi dengan menggabungkan berbagai sumber data pelanggan. Analisis dilakukan secara end-to-end mulai dari eksplorasi data, identifikasi churn driver, segmentasi pelanggan, hingga cohort analysis untuk menghasilkan insight yang actionable bagi strategi retensi dan revenue optimization.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# Perusahaan menghadapi tingkat churn yang cukup tinggi (±26%), terutama pada pelanggan baru dan pelanggan dengan kontrak jangka pendek. Churn ini berdampak langsung pada hilangnya pendapatan dan menurunkan Customer Lifetime Value (CLTV).
#
# Pertanyaan bisnis utama:
#
# - Faktor apa saja yang paling memengaruhi churn pelanggan?
# - Kapan churn paling sering terjadi dalam siklus hidup pelanggan?
# - Segmen pelanggan mana yang paling berisiko dan paling bernilai?
# - Berapa besar dampak churn terhadap pendapatan perusahaan?

# %% [markdown]
# ## Business Goals

# %% [markdown]
# **Menurunkan churn rate**
#
# Mengidentifikasi pelanggan berisiko churn (early churn, kontrak, layanan) agar dapat dilakukan tindakan pencegahan lebih awal.
#
# **Mengurangi revenue loss**
#
# Mengetahui segmen dan cohort dengan kehilangan pendapatan tertinggi untuk memprioritaskan retensi.
#
# **Meningkatkan Customer Lifetime Value (CLTV)**
#
# Fokus pada segmen bernilai tinggi dan strategi upselling/cross-selling layanan yang tepat.
#
# **Menentukan strategi retensi berbasis data**
#
# Memahami faktor utama churn (harga, kontrak, layanan, kepuasan) untuk kebijakan bisnis yang lebih efektif.
#
# **Mendukung pengambilan keputusan manajemen**
#
# Menyediakan insight cepat, terukur, dan mudah dipahami melalui dashboard interaktif.

# %% [markdown]
# # STEP 0 – Import Library

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# # STEP 1 – Load & merge data

# %%
# Load datasets
status_analysis = pd.read_csv("D:\\TakeHomeTest\\DA\dataset\\Status_Analysis.csv")
service_options = pd.read_csv("D:\\TakeHomeTest\\DA\\dataset\\Service_Options.csv")
online_services = pd.read_csv("D:\\TakeHomeTest\\DA\\dataset\\Online_Services.csv")
payment_info = pd.read_csv("D:\\TakeHomeTest\\DA\dataset\\Payment_Info.csv")
location_data = pd.read_csv("D:\\TakeHomeTest\\DA\\dataset\\Location_Data.csv")
customer_info = pd.read_csv("D:\\TakeHomeTest\\DA\\dataset\\Customer_Info.csv")

# %%
# Merge datasets on customer_id
df = status_analysis.merge(service_options, on='customer_id')
df = df.merge(online_services, on='customer_id')
df = df.merge(payment_info, on='customer_id')
df = df.merge(location_data, on='customer_id')
df = df.merge(customer_info, on='customer_id')

# %%
df = df.copy()

print(df.shape)
df.head()
# Out:
# (7043, 53)
#   customer_id  satisfaction_score  cltv customer_status  churn_score  \
# 0  0002-ORFBO                   3  2205          Stayed           65
# 1  0003-MKNFE                   5  5414          Stayed           66
# 2  0004-TLHLJ                   1  4479         Churned           71
# 3  0011-IGKFF                   1  3714         Churned           91
# 4  0013-EXCHZ                   1  3464         Churned           68
#
#   churn_label  churn_value   churn_category                   churn_reason  \
# 0          No            0   Not Applicable                            NaN
# 1          No            0   Not Applicable                            NaN
# 2         Yes            1       Competitor  Competitor had better devices
# 3         Yes            1  Dissatisfaction        Product dissatisfaction
# 4         Yes            1  Dissatisfaction            Network reliability
#
#    tenure internet_service_x phone_service_x multiple_lines  \
# 0       9                Yes             Yes             No
# 1       9                Yes             Yes            Yes
# 2       4                Yes             Yes             No
# 3      13                Yes             Yes             No
# 4       3                Yes             Yes             No
#
#    avg_monthly_gb_download unlimited_data    offer referred_a_friend  \
# 0                       16            Yes      NaN               Yes
# 1                       10             No      NaN                No
# 2                       30            Yes  Offer E                No
# 3                        4            Yes  Offer D               Yes
# 4                       11            Yes      NaN               Yes
#
#    number_of_referrals phone_service_y internet_service_y online_security  \
# 0                    2             Yes                Yes              No
# 1                    0             Yes                Yes              No
# 2                    0             Yes                Yes              No
# 3                    1             Yes                Yes              No
# 4                    3             Yes                Yes              No
#
#   online_backup device_protection premium_tech_support streaming_tv  \
# 0           Yes                No                  Yes          Yes
# 1            No                No                   No           No
# 2            No               Yes                   No           No
# 3           Yes               Yes                   No          Yes
# 4            No                No                  Yes          Yes
#
#   streaming_movies streaming_music internet_type        contract  \
# 0               No              No         Cable        One Year
# 1              Yes             Yes         Cable  Month-to-Month
# 2               No              No   Fiber Optic  Month-to-Month
# 3              Yes              No   Fiber Optic  Month-to-Month
# 4               No              No   Fiber Optic  Month-to-Month
#
#   paperless_billing    payment_method  monthly_ charges  \
# 0               Yes      Mailed check              65.6
# 1                No      Mailed check              59.9
# 2               Yes  Electronic check              73.9
# 3               Yes  Electronic check              98.0
# 4               Yes      Mailed check              83.9
#
#    avg_monthly_long_distance_charges  total_charges  total_refunds  \
# 0                              42.39         593.30           0.00
# 1                              10.69         542.40          38.33
# 2                              33.65         280.85           0.00
# 3                              27.82        1237.85           0.00
# 4                               7.38         267.40           0.00
#
#    total_extra_data_charges  total_long_distance_charges  total_revenue  \
# 0                         0                       381.51         974.81
# 1                        10                        96.21         610.28
# 2                         0                       134.60         415.45
# 3                         0                       361.66        1599.51
# 4                         0                        22.14         289.54
#
#          country       state          city  zip_code  total_population  \
# 0  United States  California  Frazier Park     93225              4498
# 1  United States  California      Glendale     91206             31297
# 2  United States  California    Costa Mesa     92627             62069
# 3  United States  California      Martinez     94553             46677
# 4  United States  California     Camarillo     93010             42853
#
#     latitude   longitude  gender  age under_30 senior_citizen partner  \
# 0  34.827662 -118.999073  Female   37       No             No     Yes
# 1  34.162515 -118.203869    Male   46       No             No      No
# 2  33.645672 -117.922613    Male   50       No             No      No
# 3  38.014457 -122.115432    Male   78       No            Yes     Yes
# 4  34.227846 -119.079903  Female   75       No            Yes     Yes
#
#   dependents  number_of_dependents married
# 0         No                     0     Yes
# 1         No                     0      No
# 2         No                     0      No
# 3         No                     0     Yes
# 4         No                     0     Yes

# %% [markdown]
# # STEP 2 – Data Understanding & Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 53 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        7043 non-null   object
#  1   satisfaction_score                 7043 non-null   int64
#  2   cltv                               7043 non-null   int64
#  3   customer_status                    7043 non-null   object
#  4   churn_score                        7043 non-null   int64
#  5   churn_label                        7043 non-null   object
#  6   churn_value                        7043 non-null   int64
#  7   churn_category                     7043 non-null   object
#  8   churn_reason                       1869 non-null   object
#  9   tenure                             7043 non-null   int64
#  10  internet_service_x                 7043 non-null   object
#  11  phone_service_x                    7043 non-null   object
#  12  multiple_lines                     7043 non-null   object
#  13  avg_monthly_gb_download            7043 non-null   int64
#  14  unlimited_data                     7043 non-null   object
#  15  offer                              3166 non-null   object
#  16  referred_a_friend                  7043 non-null   object
#  17  number_of_referrals                7043 non-null   int64
#  18  phone_service_y                    7043 non-null   object
#  19  internet_service_y                 7043 non-null   object
#  20  online_security                    7043 non-null   object
#  21  online_backup                      7043 non-null   object
#  22  device_protection                  7043 non-null   object
#  23  premium_tech_support               7043 non-null   object
#  24  streaming_tv                       7043 non-null   object
#  25  streaming_movies                   7043 non-null   object
#  26  streaming_music                    7043 non-null   object
#  27  internet_type                      5517 non-null   object
#  28  contract                           7043 non-null   object
#  29  paperless_billing                  7043 non-null   object
#  30  payment_method                     7043 non-null   object
#  31  monthly_ charges                   7043 non-null   float64
#  32  avg_monthly_long_distance_charges  7043 non-null   float64
#  33  total_charges                      7043 non-null   float64
#  34  total_refunds                      7043 non-null   float64
#  35  total_extra_data_charges           7043 non-null   int64
#  36  total_long_distance_charges        7043 non-null   float64
#  37  total_revenue                      7043 non-null   float64
#  38  country                            7043 non-null   object
#  39  state                              7043 non-null   object
#  40  city                               7043 non-null   object
#  41  zip_code                           7043 non-null   int64
#  42  total_population                   7043 non-null   int64
#  43  latitude                           7043 non-null   float64
#  44  longitude                          7043 non-null   float64
#  45  gender                             7043 non-null   object
#  46  age                                7043 non-null   int64
#  47  under_30                           7043 non-null   object
#  48  senior_citizen                     7043 non-null   object
#  49  partner                            7043 non-null   object
#  50  dependents                         7043 non-null   object
#  51  number_of_dependents               7043 non-null   int64
#  52  married                            7043 non-null   object
# dtypes: float64(8), int64(12), object(33)
# memory usage: 2.8+ MB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# churn_reason                         5174
# offer                                3877
# internet_type                        1526
# satisfaction_score                      0
# cltv                                    0
# churn_score                             0
# customer_status                         0
# churn_value                             0
# churn_label                             0
# tenure                                  0
# internet_service_x                      0
# phone_service_x                         0
# churn_category                          0
# multiple_lines                          0
# avg_monthly_gb_download                 0
# unlimited_data                          0
# referred_a_friend                       0
# number_of_referrals                     0
# phone_service_y                         0
# internet_service_y                      0
# customer_id                             0
# online_security                         0
# online_backup                           0
# premium_tech_support                    0
# device_protection                       0
# streaming_tv                            0
# streaming_movies                        0
# streaming_music                         0
# contract                                0
# paperless_billing                       0
# payment_method                          0
# monthly_ charges                        0
# avg_monthly_long_distance_charges       0
# total_charges                           0
# total_refunds                           0
# total_extra_data_charges                0
# total_long_distance_charges             0
# total_revenue                           0
# country                                 0
# state                                   0
# city                                    0
# zip_code                                0
# total_population                        0
# latitude                                0
# longitude                               0
# gender                                  0
# age                                     0
# under_30                                0
# senior_citizen                          0
# partner                                 0
# dependents                              0
# number_of_dependents                    0
# married                                 0
# dtype: int64

# %% [markdown]
# # STEP 3 – DATA CLEANING

# %% [markdown]
# ## 3.1 Rename column typo

# %%
df.rename(columns={'monthly_ charges': 'monthly_charges'}, inplace=True)

# %% [markdown]
# ## 3.2 Check duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # STEP 4 – EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ## 4.1 Target Variable (Churn)

# %%
df['churn_value'].value_counts(normalize=True)
# Out:
# churn_value
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %%
sns.countplot(x='churn_value', data=df)
plt.title('Churn Distribution')
plt.show()

# %% [markdown]
# Mayoritas pelanggan masih bertahan, tetapi tingkat churn cukup signifikan (±26%)

# %% [markdown]
# ## 4.2 Tenure vs Churn

# %%
sns.boxplot(x='churn_value', y='tenure', data=df)
plt.title('Tenure vs Churn')
plt.show()

# %% [markdown]
# **Tenure pelanggan yang churn jauh lebih rendah dibandingkan yang tidak churn.**
# Ini menunjukkan bahwa **pelanggan baru memiliki risiko churn lebih tinggi**, sehingga upaya retensi perlu difokuskan pada fase awal berlangganan.

# %%
sns.histplot(
    data=df,
    x='tenure',
    hue='churn_value',
    bins=30,
    multiple='stack'
)
plt.title('Tenure Distribution by Churn')
plt.show()

# %% [markdown]
# **Pelanggan dengan tenure 0–3 bulan memiliki tingkat churn paling tinggi**, menunjukkan bahwa periode awal berlangganan merupakan fase paling kritis dalam mempertahankan pelanggan. Strategi onboarding dan early retention sangat diperlukan pada rentang waktu ini.

# %% [markdown]
# ## 4.3 Financial Analysis

# %%
# Average monthly charges
df.groupby('churn_label')['monthly_charges'].mean()
# Out:
# churn_label
# No     61.265124
# Yes    74.441332
# Name: monthly_charges, dtype: float64

# %%
financial_cols = ['monthly_charges', 'total_revenue', 'cltv']

for col in financial_cols:
    sns.boxplot(x='churn_value', y=col, data=df)
    plt.title(f'{col} vs Churn')
    plt.show()

# %% [markdown]
# - Pada pelanggan tidak churn, Q1 ≈ 25, median ≈ 65, dan Q3 ≈ 90, sedangkan pada pelanggan churn, Q1 ≈ 58, median ≈ 80, dan Q3 ≈ 93. **Hal ini mengindikasikan bahwa semakin tinggi monthly charges, semakin besar risiko churn.**
# - Pelanggan tidak churn memiliki total revenue yang jauh lebih tinggi (Q1 ≈ 1.000, median ≈ 2.500, Q3 ≈ 5.700) dibandingkan pelanggan churn (Q1 ≈ 100, median ≈ 1.000, Q3 ≈ 2.600). **Hal ini menegaskan bahwa pelanggan yang churn umumnya memberikan kontribusi pendapatan lebih rendah**
# - Pada pelanggan tidak churn, Q1 ≈ 3.600, median ≈ 4.600, dan Q3 ≈ 5.400, sedangkan pada pelanggan churn, Q1 ≈ 3.100, median ≈ 4.300, dan Q3 ≈ 5.100.
# Hal ini mengindikasikan bahwa **pelanggan dengan CLTV lebih rendah memiliki kecenderungan churn lebih besar**

# %% [markdown]
# ## 4.4 Behavioral Analysis

# %%
sns.boxplot(
    x='churn_value',
    y='avg_monthly_gb_download',
    data=df
)
plt.title('Internet Usage vs Churn')
plt.show()

# %% [markdown]
# Pelanggan yang **churn (1)** memiliki **median penggunaan internet bulanan yang sedikit lebih tinggi dibandingkan pelanggan tidak churn (0).**
# Penggunaan internet yang lebih tinggi berkorelasi dengan **risiko churn yang sedikit lebih besar**, tetapi bukan satu-satunya faktor penentu

# %%
sns.boxplot(
    x='churn_value',
    y='number_of_referrals',
    data=df
)
plt.title('Referrals vs Churn')
plt.show()

# %% [markdown]
# Pelanggan tidak churn (0) memiliki jumlah referral yang lebih tinggi dibandingkan pelanggan churn (1), terlihat dari median dan sebaran data yang lebih besar. **Semakin banyak referral yang dilakukan pelanggan, semakin kecil kemungkinan pelanggan melakukan churn**, sehingga referral dapat menjadi indikator loyalitas pelanggan.

# %% [markdown]
# ## 4.5 Service Adoption vs Churn

# %%
service_cols = [
    'online_security','online_backup','device_protection',
    'premium_tech_support','streaming_tv',
    'streaming_movies','streaming_music'
]

service_summary = (
    df.groupby('churn_value')[service_cols]
      .apply(lambda x: (x == 'Yes').mean())
      .T
)

service_summary.plot(kind='barh', figsize=(8,6))
plt.title('Service Adoption by Churn')
plt.show()

# %%
print((service_summary * 100).round(2))
# Out:
# churn_value               0      1
# online_security       33.32  15.78
# online_backup         36.84  27.98
# device_protection     36.28  29.16
# premium_tech_support  33.51  16.59
# streaming_tv          36.59  43.55
# streaming_movies      36.99  43.77
# streaming_music       34.02  38.95

# %% [markdown]
# Pelanggan yang tidak menggunakan layanan tambahan cenderung memiliki risiko churn jauh lebih tinggi. Layanan seperti online security dan premium tech support terbukti paling efektif dalam menurunkan churn.
#
# Layanan keamanan dan dukungan teknis berperan penting dalam menekan churn, sedangkan layanan streaming tidak secara efektif meningkatkan loyalitas pelanggan.

# %% [markdown]
# ## 4.6 Satisfaction

# %%
summary = (
    df.groupby('churn_label')
      .agg(
          avg_satisfaction=('satisfaction_score','mean'),
          customers=('customer_id','count')
      )
)

summary['percentage'] = summary['customers'] / summary['customers'].sum() * 100
summary
# Out:
#              avg_satisfaction  customers  percentage
# churn_label
# No                   3.789911       5174   73.463013
# Yes                  1.736223       1869   26.536987

# %%
df.groupby('churn_label')['satisfaction_score'].mean()
sns.barplot(
    x='churn_label',
    y='satisfaction_score',
    data=df,
    estimator=np.mean
)
plt.title('Satisfaction Score by Churn Status')
plt.show()

# %% [markdown]
# Pelanggan **tidak churn (No)** memiliki **rata-rata tingkat kepuasan yang jauh lebih tinggi (3,79)** dibandingkan pelanggan **churn (Yes)** yang hanya sebesar **1,74.**
#
# Sebanyak 73,46% pelanggan tidak churn, sedangkan 26,54% pelanggan churn.
# **Tingkat kepuasan pelanggan berpengaruh kuat terhadap churn**, semakin rendah kepuasan semakin besar kemungkinan pelanggan berhenti berlangganan.

# %% [markdown]
# ## 4.8 Contrac type vc Churn

# %%
churn_contract = (
    df.groupby('contract')['churn_label']
      .apply(lambda x: (x == 'Yes').mean() * 100)
      .reset_index(name='churn_rate')
      .sort_values('churn_rate', ascending=False)
)

churn_contract
plt.figure(figsize=(6,4))
plt.bar(churn_contract['contract'], churn_contract['churn_rate'])
plt.title('Churn Rate by Contract Type')
plt.ylabel('Churn Rate (%)')
plt.show()

# %%
print("\n=== Churn Rate by Contract Type (%) ===")
print(churn_contract.round(2))
# Out:
# === Churn Rate by Contract Type (%) ===
#          contract  churn_rate
# 0  Month-to-Month       45.84
# 1        One Year       10.71
# 2        Two Year        2.55

# %% [markdown]
# Semakin panjang durasi kontrak, semakin rendah risiko churn, sehingga mendorong pelanggan beralih ke kontrak jangka panjang merupakan strategi efektif untuk meningkatkan retensi.

# %% [markdown]
# ## 4.8 Churn Reason (Churners Only)

# %%
df[df['churn_value'] == 1]['churn_reason'].value_counts().head(10)
# Out:
# churn_reason
# Competitor had better devices                313
# Competitor made better offer                 311
# Attitude of support person                   220
# Don't know                                   130
# Competitor offered more data                 117
# Competitor offered higher download speeds    100
# Attitude of service provider                  94
# Price too high                                78
# Product dissatisfaction                       77
# Network reliability                           72
# Name: count, dtype: int64

# %% [markdown]
# # STEP 5 – FEATURE ENGINEERING (SEGMENTATION)

# %%
# Total streaming services
df['num_streaming_services'] = (
    (df['streaming_tv'] == 'Yes').astype(int) +
    (df['streaming_movies'] == 'Yes').astype(int) +
    (df['streaming_music'] == 'Yes').astype(int)
)

# Security service
df['has_security_service'] = (
    (df['online_security'] == 'Yes') |
    (df['online_backup'] == 'Yes') |
    (df['device_protection'] == 'Yes')
).astype(int)

# Total services used
df['total_services_used'] = (
    df[service_cols] == 'Yes'
).sum(axis=1)

# %% [markdown]
# # STEP 6 – CUSTOMER SEGMENTATION (K-MEANS)

# %% [markdown]
# ## 6.1 Feature Selection

# %%
seg_features = [
    'tenure',
    'monthly_charges',
    'total_revenue',
    'cltv',
    'avg_monthly_gb_download',
    'total_services_used'
]

X = df[seg_features]

# %% [markdown]
# ## 6.2 Feature Scaling

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 6.3 Elbow Method

# %%
inertia = []

for k in range(2, 8):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X_scaled)
    inertia.append(km.inertia_)

plt.plot(range(2, 8), inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## 6.4 Silhouette Score

# %%
for k in range(2, 6):
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    print(f'k={k}, silhouette={score:.3f}')
# Out:
# k=2, silhouette=0.334
# k=3, silhouette=0.290
# k=4, silhouette=0.274
# k=5, silhouette=0.227

# %% [markdown]
# Meskipun k = 2 memiliki silhouette score tertinggi (0,334), k = 3 dipilih karena lebih mudah diinterpretasikan dan lebih relevan secara bisnis. Dengan tiga cluster, pelanggan dapat dikelompokkan menjadi segmen yang lebih bermakna (misalnya low, medium, dan high value / low–medium–high risk churn), sehingga strategi pemasaran dan retensi dapat dibuat lebih spesifik dan actionable.
#
# Pemilihan k = 3 merupakan kompromi yang tepat antara kualitas clustering dan kegunaan bisnis.

# %% [markdown]
# ## 6.5 Fit Final Model

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# %% [markdown]
# ## 6.6 Cluster Profiling

# %%
cluster_profile = (
    df.groupby('cluster')
      .agg(
          customers=('customer_id', 'count'),
          avg_tenure=('tenure', 'mean'),
          avg_revenue=('total_revenue', 'mean'),
          avg_cltv=('cltv', 'mean'),
          churn_rate=('churn_value', 'mean')
      )
)

cluster_profile
# Out:
#          customers  avg_tenure  avg_revenue     avg_cltv  churn_rate
# cluster
# 0             2005   27.803491  1343.826244  4435.745137    0.136658
# 1             2150   58.826977  6664.778879  5111.605116    0.145581
# 2             2888   15.846953  1505.362008  3846.143698    0.443906

# %% [markdown]
# Cluster 1 adalah aset utama perusahaan, sementara Cluster 2 adalah prioritas utama penanganan churn.

# %% [markdown]
# # STEP 7 – COHORT ANALYSIS

# %% [markdown]
# ## 7.1 Tenure Cohort

# %%
df['tenure_cohort'] = pd.cut(
    df['tenure'],
    bins=[0,3,6,12,24,100],
    labels=['0–3','4–6','7–12','13–24','25+'],
    include_lowest=True
)

# %% [markdown]
# ## 7.2 Cohort Metrics

# %%
cohort_summary = (
    df.groupby('tenure_cohort')
      .agg(
          customers=('customer_id','count'),
          churn_rate=('churn_value','mean'),
          avg_revenue=('total_revenue','mean'),
          avg_cltv=('cltv','mean')
      )
)

cohort_summary
# Out:
#                customers  churn_rate  avg_revenue     avg_cltv
# tenure_cohort
# 0–3                 1062    0.562147   131.699840  4043.559322
# 4–6                  419    0.446301   395.529737  4014.758950
# 7–12                 705    0.358865   769.323660  4038.127660
# 13–24               1024    0.287109  1560.117500  4015.195312
# 25+                 3833    0.140360  4937.543960  4710.774589

# %% [markdown]
# Churn rate **menurun tajam seiring bertambahnya tenure pelanggan.**
# Pelanggan **0–3** bulan memiliki churn rate tertinggi **(56,8%)** dengan revenue terendah, sedangkan pelanggan **25+** bulan memiliki churn rate terendah **(14,0%)*8 serta **rata-rata revenue dan CLTV tertinggi.**

# %% [markdown]
# ## 7.3 Cohort Heatmap (Churn)

# %%
sns.heatmap(
    cohort_summary[['churn_rate']],
    annot=True,
    cmap='Reds'
)
plt.title('Churn Rate by Tenure Cohort')
plt.show()

# %% [markdown]
# Masa awal berlangganan adalah fase paling kritis churn, sementara pelanggan jangka panjang merupakan kontributor nilai terbesar dan paling loyal.

# %% [markdown]
# # STEP 8 – COMBINE COHORT + SEGMENTATION

# %%
combo_analysis = (
    df.groupby(['cluster','tenure_cohort'])
      .agg(
          customers=('customer_id','count'),
          churn_rate=('churn_value','mean'),
          avg_revenue=('total_revenue','mean')
      )
      .reset_index()
)

combo_analysis
# Out:
#     cluster tenure_cohort  customers  churn_rate  avg_revenue
# 0         0           0–3        407    0.380835    77.123612
# 1         0           4–6        125    0.200000   238.444480
# 2         0          7–12        227    0.149780   462.235022
# 3         0         13–24        316    0.085443   944.660854
# 4         0           25+        930    0.035484  2397.566204
# 5         1           0–3          0         NaN          NaN
# 6         1           4–6          0         NaN          NaN
# 7         1          7–12          0         NaN          NaN
# 8         1         13–24          6    0.500000  3159.333333
# 9         1           25+       2144    0.144590  6674.588895
# 10        2           0–3        655    0.674809   165.612092
# 11        2           4–6        294    0.551020   462.317687
# 12        2          7–12        478    0.458159   915.158640
# 13        2         13–24        702    0.376068  1823.492151
# 14        2           25+        759    0.256917  3143.018235

# %% [markdown]
# **Cluster 0 (Stabil Bertumbuh)**
#
# Terlihat pola yang sangat jelas: semakin lama tenure, semakin rendah churn rate (dari 38,7% di 0–3 bulan menjadi hanya 3,5% di 25+ bulan), seiring dengan kenaikan revenue yang konsisten. Ini menunjukkan efektivitas retensi jangka panjang pada cluster ini.
#
# **Cluster 1 (High Value Loyal)**
#
# Hampir seluruh pelanggan berada pada tenure 25+ bulan dengan churn rate relatif rendah (14,5%) dan average revenue tertinggi. Cluster ini merepresentasikan pelanggan paling matang dan bernilai tinggi.
#
# **Cluster 2 (High Risk Churn)**
#
# Memiliki churn rate sangat tinggi di semua tenure, terutama pada fase awal (68% pada 0–3 bulan). Meskipun churn menurun seiring tenure bertambah, nilainya tetap tinggi bahkan pada 25+ bulan (25,7%). Revenue meningkat, tetapi tidak cukup menekan risiko churn.

# %% [markdown]
# ## Heatmap: Cluster × Cohort Churn

# %%
pivot_churn = combo_analysis.pivot(
    index='cluster',
    columns='tenure_cohort',
    values='churn_rate'
)

sns.heatmap(pivot_churn, annot=True, cmap='Reds')
plt.title('Churn Rate by Cluster & Tenure Cohort')
plt.show()

# %% [markdown]
# Cluster 2 membutuhkan intervensi agresif sejak awal, Cluster 0 menunjukkan jalur pertumbuhan yang sehat, dan Cluster 1 adalah aset utama yang harus dipertahankan.

# %% [markdown]
# # STEP 9 — Churn Driver Analysis

# %% [markdown]
# ## 9.1 Churn Rate by Key Drivers

# %% [markdown]
# ### 9.1.1 Contract Type

# %%
churn_by_contract = (
    df.groupby('contract')['churn_value']
      .mean()
      .sort_values(ascending=False)
      .reset_index(name='churn_rate')
)

churn_by_contract
# Out:
#          contract  churn_rate
# 0  Month-to-Month    0.458449
# 1        One Year    0.107097
# 2        Two Year    0.025491

# %%
sns.barplot(
    data=churn_by_contract,
    x='contract',
    y='churn_rate'
)
plt.title('Churn Rate by Contract Type')
plt.ylabel('Churn Rate')
plt.show()

# %% [markdown]
# Kontrak jangka pendek merupakan faktor risiko utama churn, sedangkan kontrak jangka panjang sangat efektif dalam menekan churn. Strategi konversi pelanggan ke kontrak 1–2 tahun akan berdampak signifikan pada retensi.

# %% [markdown]
# ### 9.1.2 Payment Method

# %%
churn_by_payment = (
    df.groupby('payment_method')['churn_value']
      .mean()
      .sort_values(ascending=False)
      .reset_index(name='churn_rate')
)

churn_by_payment
# Out:
#               payment_method  churn_rate
# 0           Electronic check    0.452854
# 1               Mailed check    0.191067
# 2  Bank transfer (automatic)    0.167098
# 3    Credit card (automatic)    0.152431

# %%
sns.barplot(
    data=churn_by_payment,
    x='payment_method',
    y='churn_rate'
)
plt.xticks(rotation=45)
plt.title('Churn Rate by Payment Method')
plt.show()

# %% [markdown]
# Pelanggan yang menggunakan Electronic check memiliki churn rate paling tinggi (45,29%), jauh dibandingkan metode pembayaran otomatis seperti Credit card (15,24%) dan Bank transfer (16,71%).

# %% [markdown]
# # STEP 10 - Early Churn Analysis

# %% [markdown]
# ## 10.1 Define Early Churn

# %%
df['early_churn'] = np.where(
    (df['tenure'] <= 3) & (df['churn_value'] == 1),
    1, 0
)

df['early_churn'].mean()
# Out:
# np.float64(0.08476501490841971)

# %% [markdown]
# ### 10.1.1 Early Churn by Contract

# %%
early_churn_contract = (
    df[df['tenure'] <= 3]
    .groupby('contract')['churn_value']
    .mean()
    .reset_index(name='early_churn_rate')
)

early_churn_contract
# Out:
#          contract  early_churn_rate
# 0  Month-to-Month          0.593220
# 1        One Year          0.074074
# 2        Two Year          0.000000

# %%
sns.barplot(
    data=early_churn_contract,
    x='contract',
    y='early_churn_rate'
)
plt.title('Early Churn Rate (0–3 Months) by Contract')
plt.show()

# %% [markdown]
# Early churn rate secara keseluruhan sebesar ±8,5%, namun perbedaannya sangat tajam antar jenis kontrak.
# Pelanggan dengan kontrak Month-to-Month memiliki early churn sangat tinggi (59,3%), sementara kontrak One Year jauh lebih rendah (7,4%) dan Two Year hampir nol.

# %% [markdown]
# # STEP 11 — Revenue Impact Analysis

# %% [markdown]
# ## 11.1 Total Revenue Lost

# %%
total_revenue_lost = df.loc[df['churn_value'] == 1, 'total_revenue'].sum()
total_revenue_lost
# Out:
# np.float64(3684459.8200000003)

# %% [markdown]
# ## Revenue Lost by Cluster

# %%
revenue_lost_cluster = (
    df[df['churn_value'] == 1]
    .groupby('cluster')['total_revenue']
    .sum()
    .reset_index(name='revenue_lost')
)

revenue_lost_cluster
# Out:
#    cluster  revenue_lost
# 0        0     129344.87
# 1        1    2030858.08
# 2        2    1524256.87

# %%
sns.barplot(
    data=revenue_lost_cluster,
    x='cluster',
    y='revenue_lost'
)
plt.title('Revenue Lost by Customer Cluster')
plt.show()

# %% [markdown]
# Cluster 1 menyumbang kehilangan revenue terbesar (±2,03 juta), meskipun churn rate-nya relatif rendah. Hal ini terjadi karena nilai revenue per pelanggan sangat tinggi, sehingga setiap churn berdampak besar secara finansial.
#
# Cluster 2 memiliki revenue lost sangat tinggi (±1,52 juta) akibat churn rate yang tinggi, meskipun nilai pelanggan lebih rendah dibanding Cluster 1.
#
# Cluster 0 menyumbang revenue lost paling kecil (±129 ribu) karena churn rate rendah dan nilai pelanggan menengah.
#
# **Cluster 1 adalah risiko finansial terbesar per churn, sedangkan Cluster 2 adalah sumber churn terbanyak—keduanya harus menjadi prioritas utama strategi retensi.**

# %%
dashboard_cols = [
    # Identity
    'customer_id',

    # Churn
    'churn_value',
    'churn_label',
    'customer_status',
    'churn_category',
    'churn_reason',

    # Lifecycle
    'tenure',
    'tenure_cohort',
    'cluster',
    'early_churn',

    # Financial
    'monthly_charges',
    'total_charges',
    'total_revenue',
    'cltv',

    # Contract & Payment
    'contract',
    'payment_method',
    'paperless_billing',

    # Satisfaction & Engagement
    'satisfaction_score',
    'number_of_referrals',

    # Services
    'online_security',
    'online_backup',
    'device_protection',
    'premium_tech_support',
    'streaming_tv',
    'streaming_movies',
    'streaming_music',

    # Engineered
    'num_streaming_services',
    'has_security_service',
    'total_services_used'
]

df_dashboard = df[dashboard_cols].copy()
df_dashboard.to_csv("customer_churn_dashboard.csv", index=False)

# %%
df_dashboard.info()
df_dashboard.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   churn_value             7043 non-null   int64
#  2   churn_label             7043 non-null   object
#  3   customer_status         7043 non-null   object
#  4   churn_category          7043 non-null   object
#  5   churn_reason            1869 non-null   object
#  6   tenure                  7043 non-null   int64
#  7   tenure_cohort           7043 non-null   category
#  8   cluster                 7043 non-null   int32
#  9   early_churn             7043 non-null   int64
#  10  monthly_charges         7043 non-null   float64
#  11  total_charges           7043 non-null   float64
#  12  total_revenue           7043 non-null   float64
#  13  cltv                    7043 non-null   int64
#  14  contract                7043 non-null   object
#  15  payment_method          7043 non-null   object
#  16  paperless_billing       7043 non-null   object
#  17  satisfaction_score      7043 non-null   int64
#  18  number_of_referrals     7043 non-null   int64
#  19  online_security         7043 non-null   object
#  20  online_backup           7043 non-null   object
#  21  device_protection       7043 non-null   object
#  22  premium_tech_support    7043 non-null   object
#  23  streaming_tv            7043 non-null   object
#  24  streaming_movies        7043 non-null   object
#  25  streaming_music         7043 non-null   object
#  26  num_streaming_services  7043 non-null   int64
#  27  has_security_service    7043 non-null   int64
#  28  total_services_used     7043 non-null   int64
# dtypes: category(1), float64(3), int32(1), int64(9), object(15)
# memory usage: 1.5+ MB
#   customer_id  churn_value churn_label customer_status   churn_category  \
# 0  0002-ORFBO            0          No          Stayed   Not Applicable
# 1  0003-MKNFE            0          No          Stayed   Not Applicable
# 2  0004-TLHLJ            1         Yes         Churned       Competitor
# 3  0011-IGKFF            1         Yes         Churned  Dissatisfaction
# 4  0013-EXCHZ            1         Yes         Churned  Dissatisfaction
#
#                     churn_reason  tenure tenure_cohort  cluster  early_churn  \
# 0                            NaN       9          7–12        2            0
# 1                            NaN       9          7–12        2            0
# 2  Competitor had better devices       4           4–6        2            0
# 3        Product dissatisfaction      13         13–24        2            0
# 4            Network reliability       3           0–3        2            1
#
#    monthly_charges  total_charges  total_revenue  cltv        contract  \
# 0             65.6         593.30         974.81  2205        One Year
# 1             59.9         542.40         610.28  5414  Month-to-Month
# 2             73.9         280.85         415.45  4479  Month-to-Month
# 3             98.0        1237.85        1599.51  3714  Month-to-Month
# 4             83.9         267.40         289.54  3464  Month-to-Month
#
#      payment_method paperless_billing  satisfaction_score  \
# 0      Mailed check               Yes                   3
# 1      Mailed check                No                   5
# 2  Electronic check               Yes                   1
# 3  Electronic check               Yes                   1
# 4      Mailed check               Yes                   1
#
#    number_of_referrals online_security online_backup device_protection  \
# 0                    2              No           Yes                No
# 1                    0              No            No                No
# 2                    0              No            No               Yes
# 3                    1              No           Yes               Yes
# 4                    3              No            No                No
#
#   premium_tech_support streaming_tv streaming_movies streaming_music  \
# 0                  Yes          Yes               No              No
# 1                   No           No              Yes             Yes
# 2                   No           No               No              No
# 3                   No          Yes              Yes              No
# 4                  Yes          Yes               No              No
#
#    num_streaming_services  has_security_service  total_services_used
# 0                       1                     1                    3
# 1                       2                     0                    2
# 2                       0                     1                    1
# 3                       2                     1                    4
# 4                       1                     0                    2
